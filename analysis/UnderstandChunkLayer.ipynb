# %% [markdown]
# Try to get a sense of what is happening in with the chunk layer

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
sns.set()
from decodedoutputdefs import Precision #class with the compiled definitions

# %%
base_file = base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/decodedrew/RewThresh30new/"

files = os.listdir(base_file)
files = [f for f in files if '.csv' in f]
files = [base_file+f for f in files if 'EpcLog' not in f]
files = [f for f in files if 'tol' not in f]
#going through the files one at a time - because combining all models together does not make sense. 
for f in files:
    err = Precision()
    recall1,recall2,recall3=err.err_recall_type_sir3(f)
    #print(f)
    plt.figure()
    model = f.split('/')[-1].split('_Stripes')[0]
    plt.hist(recall1)
    plt.title('Recall 1 Errors ,' +model)
    plt.figure()
    plt.hist(recall2)
    plt.title('Recall 2 Errors ,'+model)
    plt.figure()
    plt.hist(recall3)
    plt.title('Recall 3 Errors ,'+model)

# %%
#model that I was visualizing in the gui, it did not learn well for one of the recalls, but learned well for the other. 
file= 'C:/Users/Aneri/go/src/leabra/examples/sir_proj/sir2_chunk/results/hybridmodeltestwithgui.csv'
df = pd.read_csv('C:/Users/Aneri/go/src/leabra/examples/sir_proj/sir2_chunk/results/hybridmodeltestwithgui.csv',sep = '\t')

# %%
file= 'C:/Users/Aneri/go/src/leabra/examples/sir_proj/sir2_chunk/results/hybridmodel9testwithgui.csv'
err = Precision()
recall1,recall2=err.err_recall_type(file)
#print(f)
plt.figure()
model = file.split('/')[-1].split('_Stripes')[0]
plt.hist(recall1)
plt.title('Recall 1 Errors ,' +model)
plt.figure()
plt.hist(recall2)
plt.title('Recall 2 Errors ,'+model)
# Out:
# Text(0.5, 1.0, 'Recall 2 Errors ,hybridmodel9testwithgui.csv')

# %%
#lets look at some existing models for sir2_chunk and see on a grander scheme, how many of the models learn, and how much do they learn. 

base_file = base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/"

files = os.listdir(base_file)
files = [f for f in files if '.csv' in f]
files = [base_file+f for f in files if 'EpcLog' not in f]
files = [f for f in files if 'tol' not in f]

# %%
#going through the files one at a time - because combining all models together does not make sense. 
for f in files:
    err = Precision()
    recall1,recall2=err.err_recall_type(f)
    #print(f)
    plt.figure()
    model = f.split('/')[-1].split('_Stripes')[0]
    plt.hist(recall1)
    plt.title('Recall 1 Errors ,' +model)
    plt.figure()
    plt.hist(recall2)
    plt.title('Recall 2 Errors ,'+model)

# %%
#testing with just 1 file.
#file = files[1]
file =  'C:/Users/Aneri/go/src/leabra/examples/sir_proj/sir2_chunk/results/hybridmodel2testwithgui.csv'

err = Precision()
recall1,recall2=err.err_recall_type(file)
print(file)
# Out:
# C:/Users/Aneri/go/src/leabra/examples/sir_proj/sir2_chunk/results/hybridmodel2testwithgui.csv

# %%
plt.hist(recall1)
plt.title('Recall 1 Errors')
plt.figure()
plt.hist(recall2)
plt.title('Recall 2 Errors')
# Out:
# Text(0.5, 1.0, 'Recall 2 Errors')

# %%
plt.

# %%
def recall_trials_numstims:
    #want to figure out how many recall trials there is actually 2 stimuli to be maintained. 
    return one_stim,two_stim
    
def error_based_on_error_type():
    #want to figure out if the model is selectively doing well on one or the other type of recall trial.
