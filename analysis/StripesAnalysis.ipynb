# %% [markdown]
# Stripes Analysis: created 10/20/2021
# Trying to analyze how the number of stripes relates to performance
# also trying to see how to analyze the chunk.

# %% [markdown]
# Goals:
#
# 1) See if chunk stimulus encoded in PFC
# 2) See if input stimulus is encoded in PFC
# 3) See how what is maintained in PFC affects chunk

# %% [markdown]
# How to Accomplish Goals:
#
# 1) Write code to compare what is in input, chunk and pfc stripes

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
sns.set()
from decodedoutputdefs import Precision #class with the compiled definitions

# %%
file_loc = "Z:/leabra/examples/workingmemory/sir2_chunk/results/"
files = os.listdir(file_loc)
full_files= [file_loc+f for f in files if '_Stripes' in f]

# %%
st = Precision(full_files[0])
st.plot_stripes(full_files,[1,2,4,5,6,7,8], file_loc+'stripes.png')
