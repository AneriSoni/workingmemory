# %% [markdown]
# Created 10/25/2021
#
# Purpose: cdf of expected distributions

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
#import seaborn as sns
import os
#sns.set()
import scipy

# %%
x = np.linspace(-1,1,100)
plt.rcParams['figure.figsize'] = [3, 3]
plt.plot(x,np.exp(5*-x**2))
plt.ylim([0,1.2])

plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)

# %%
plt.rcParams['figure.figsize'] = [3, 3]
plt.plot(x,(np.exp(40*-x**2)+0.2)/1.2)
plt.ylim([0,1.2])
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)

# %%
plt.plot(x,np.ones_like(x)/np.exp(1))
plt.ylim([0,1.2])
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)

# %%
#not needed
fig, ax = plt.subplots(1, 1)
kappa = 3.99
x = np.linspace(scipy.stats.vonmises.ppf(0.01, kappa),scipy.stats.vonmises.ppf(0.99, kappa), 100)
ax.plot(x, scipy.stats.vonmises.pdf(x, kappa), lw=5, alpha=0.6, label='vonmises pdf')
plt.tick_params(axis='both', which='both', bottom=False, top=False, labelbottom=False, right=False, left=False, labelleft=False)
