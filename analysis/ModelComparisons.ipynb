# %% [markdown]
# Created 1/28/2022
#
# The point of this is to keep a comparison of the different models and their perofmrnace

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
sns.set()
from decodedoutputdefs import Precision #class with the compiled definitions

# %%
name = 'Sir1 Chunk, 3 Stripes'
plt.hist(err_sir1_chunk_3Stripe, bins = 70)
plt.title(name)
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.ylim([0,2500])
plt.xlim([-30,30])
plt.show()

# %%
#Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_nochunk_1Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_nochunk_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_nochunk_3Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_chunk_1Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_chunk_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_chunk_3Stripe = p.mult_models(full_files)

# %%
#sir1 Ring
base = "Z:/leabra/examples/workingmemory/sir1/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir1_nochunk_1Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir1/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir1_nochunk_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir1/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir1_nochunk_3Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir1_chunk/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir1_chunk_1Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir1_chunk/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir1_chunk_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir1_chunk/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir1_chunk_3Stripe = p.mult_models(full_files)

# %%
#sir2 no chunk model; 1 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir2 NO CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 no chunk model; 3 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir2 NO CHUNK- 3 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 no chunk model; 2 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir2 NO CHUNK- 2 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2chunk model; 2 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir2 CHUNK- 2 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2chunk model; 1 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir2 CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2chunk model; 3 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir2 CHUNK- 3 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir1 no chunk model; 1 stripe; Ring;
base = "Z:/leabra/examples/workingmemory/sir1/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir1 NO CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir1 no chunk model; 2 stripe; Ring;
base = "Z:/leabra/examples/workingmemory/sir1/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir1 NO CHUNK- 2 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir1 no chunk model; 3 stripe; Ring;
base = "Z:/leabra/examples/workingmemory/sir1/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir1 NO CHUNK- 3 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir1 chunk model; 1 stripe; Ring;
base = "Z:/leabra/examples/workingmemory/sir1_chunk/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir1 CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
#sir1 chunk model; 2 stripe; Ring;
base = "Z:/leabra/examples/workingmemory/sir1_chunk/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir1 CHUNK- 2 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir1 chunk model; 3 stripe; Ring;
base = "Z:/leabra/examples/workingmemory/sir1_chunk/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir1 CHUNK- 3 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir1, no chunk; 2 stripes
base = "C:/Users/Aneri/go/src/leabra/examples/sir_proj/sir1/"
files = ['trial1.csv']
full_files = [base+f for f in files]
p = Precision()
err = p.mult_models(full_files, sep = ',')
plt.hist(err)
plt.title('Error Distribution for All Recall Trials, Sir1 NO CHUNK- 2 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 no chunk model; 1 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/StimRange0to45/1StripeMore/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 40)
plt.title('Error Distribution for All Recall Trials, Sir2 NO CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 no chunk model; 2 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/StimRange0to45/2Stripes/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err)
plt.title('Error Distribution for All Recall Trials, Sir2 NO CHUNK - 2 Stripes')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 chunk model, 2 stripes; RING; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/StimRange0to45/2Stripes/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err)
plt.title('Error Distribution for All Recall Trials, Sir2 CHUNK - 2 Stripes')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 chunk model 1 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/StimRange0to45/1StripeMore/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 50)
plt.title('Error Distribution for All Recall Trials, Sir2 CHUNK - 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 no chunk model; 1 stripe; Ring
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
plt.subplot(1,2,1)
err = p.mult_models(full_files)
plt.ylim([0,120])
plt.hist(err, bins = 40)
plt.title('Sir2 NO CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')

#sir2 chunk model 1 stripe; Ring
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.subplot(1,2,2)
plt.ylim([0,120])
plt.hist(err, bins = 40)
plt.title('Sir2 CHUNK - 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#sir2 no chunk model; 1 stripe; Ring; stim 0  to45
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/StimRange0to45/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
plt.subplot(1,2,1)
err = p.mult_models(full_files)
plt.ylim([0,510])
plt.hist(err, bins = 40)
plt.title('Sir2 NO CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')

#sir2 chunk model 1 stripe; Ring;stom 0  to45
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/StimRange0to45/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.subplot(1,2,2)
plt.ylim([0,510])
plt.hist(err, bins = 40)
plt.title('Sir2 CHUNK - 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#sir2 no chunk model; 1 stripe; Ring
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 40)
plt.title('Error Distribution for All Recall Trials, Sir2 NO CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 no chunk model; 2 stripe; Ring
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err)
plt.title('Error Distribution for All Recall Trials, Sir2 NO CHUNK - 2 Stripes')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 chunk model 1 stripe; Ring
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 40)
plt.title('Error Distribution for All Recall Trials, Sir2 CHUNK - 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
len(err)
# Out:
# 1650

# %%
#sir2 chunk model, 2 stripes; RING
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripes/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err)
plt.title('Error Distribution for All Recall Trials, Sir2 CHUNK - 2 Stripes')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 model, 2 stripes (no chunk layer)
base = "Z:/leabra/examples/workingmemory/sir2_new/results/"
files = ['model1_Base.csv','model3_Base.csv','model4_Base.csv']
full_files = [base+f for f in files]


p = Precision()
err = p.mult_models(full_files)
plt.hist(err)
plt.title('Error Distribution for All Recall Trials')
plt.xlabel('Error')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 model, 2 stripes with chunk layer
base = "C:/Users/Aneri/go/src/leabra/examples/sir_proj/sir2_chunk/results/"
files = ['base.csv', 'base1.csv', 'base4.csv']
full_files = [base+f for f in files]
p = Precision()
err = p.mult_models(full_files,sep= ',')
plt.hist(err)
plt.title('Error Distribution for All Recall Trials')
plt.xlabel('Error')
plt.ylabel('Frequency')
plt.show()
