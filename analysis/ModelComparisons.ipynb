# %% [markdown]
# Created 1/28/2022
#
# The point of this is to keep a comparison of the different models and their perofmrnace

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
sns.set()
from decodedoutputdefs import Precision, training_curve_indv, training_curve_average #class with the compiled definitions

# %%
# base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/contexp/"
# files = os.listdir(base)
# full_files = [base+f for f in files if 'EpcLog' not in f]
# p = Precision()
# err_sir2_chunk_orig = p.mult_models(full_files)

# plt.figure()
# plt.hist(err_sir2_chunk_orig, bins = 50)
# plt.title('Sir2 Chunk, Unit Difference, ContExp')
# plt.show()


base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/decodedrew/contexp/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2 Chunk, Decoded, ContExp')
plt.show()


base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/decodedrew/cont/StimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2 Chunk, Decoded, ContLinear')
plt.show()

# base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/cont/"
# files = os.listdir(base)
# full_files = [base+f for f in files if 'EpcLog' not in f]
# p = Precision()
# err_sir2_chunk_orig = p.mult_models(full_files)

# plt.figure()
# plt.hist(err_sir2_chunk_orig, bins = 50)
# plt.title('Sir2 Chunk, Unit Difference, ContLinear')
# plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/contexp/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Unit Difference, ContExp')
plt.show()


base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/decodedrew/contexp/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Decoded, ContExp')
plt.show()


base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/decodedrew/cont/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Decoded, ContLinear')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/cont/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Unit Difference, ContLinear')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-7e9e0c184b25> in <module>
#      15 full_files = [base+f for f in files if 'EpcLog' not in f]
#      16 p = Precision()
# ---> 17 err_sir2_chunk_orig = p.mult_models(full_files)
#      18
#      19 plt.figure()
#
# ~\go\src\leabra\examples\sir_proj\analysis\decodedoutputdefs.py in mult_models(self, files, sep)
#     177         dat = pd.DataFrame()
#     178         for f in files:
# --> 179             dat = dat.append(pd.read_csv(f,sep=sep))
#     180         self.dat = dat
#     181
#
# ...

# %%
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/contexp/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, Unit Difference, ContExp')
plt.show()


base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/decodedrew/contexp/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, Decoded, ContExp')
plt.show()


base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/decodedrew/cont/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, Decoded, ContLinear')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/cont/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, Unit Difference, ContLinear')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-3b708a530a03> in <module>
#      27 full_files = [base+f for f in files if 'EpcLog' not in f]
#      28 p = Precision()
# ---> 29 err_sir2_chunk_orig = p.mult_models(full_files)
#      30
#      31 plt.figure()
#
# ~\go\src\leabra\examples\sir_proj\analysis\decodedoutputdefs.py in mult_models(self, files, sep)
#     177         dat = pd.DataFrame()
#     178         for f in files:
# --> 179             dat = dat.append(pd.read_csv(f,sep=sep))
#     180         self.dat = dat
#     181
#
# ...

# %%
#calc mse
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/decodedrew/contexp/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err = p.mult_models(full_files)
print(np.sqrt(np.mean(err**2)))

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/decodedrew/contexpNoStimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err = p.mult_models(full_files)
print(np.sqrt(np.mean(err**2)))
# Out:
# 37.68075851668625
# 36.59759406795831

# %%
base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/decodedrew/contexpNoStimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err = p.mult_models(full_files)
print(np.sqrt(np.mean(err**2)))

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/decodedrew/contexpNoStimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err = p.mult_models(full_files)
print(np.sqrt(np.mean(err**2)))
# Out:
# 42.293909248982736
# 43.4448979167544

# %%
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/contexp/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, Unit Difference')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/contexpNoStimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, Unit Difference, No Stim Loc')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/decodedrew/contexpNoStimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, Decoded; No StimLoc')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/decodedrew/contexp/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, Decoded')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/cont/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, Unit Difference; No StimLoc')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/RewThresh55/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, Unit Difference; No StimLoc')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/decodedrew/cont/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, No StimLoc')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/decodedrew/RewThresh30new/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, No StimLoc')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/decodedrew/contexpNoStimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)
np.mean((err_sir2_chunk_orig)**2)
# Out:
# 1788.7747595611872

# %%
base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/decodedrew/contexpNoStimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)
np.mean((err_sir2_chunk_orig)**2)
# Out:
# 1887.4591549972106

# %%
base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/contexp/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Unit Difference; ContExp')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/contexpNoStimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Unit Difference; ContExp No StimLoc')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/decodedrew/contexp/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Decoded, ContExp')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/decodedrew/contexpNoStimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Decoded; ContExpNoStimLoc')
plt.ylabel('Frequency')
plt.xlabel('Error (in Degrees)')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/contexp/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_chunk, Unit Difference; ContExp')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/contexpNoStimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_chunk, Unit Difference; ContExp No StimLoc')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/decodedrew/contexp/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_chunk, Decoded, ContExp')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/decodedrew/contexpNoStimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_chunk, Decoded; ContExpNoStimLoc')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/contexp/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Unit Difference; ContExp')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/contexpNoStimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Unit Difference; ContExp No StimLoc')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/decodedrew/contexp/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Decoded, ContExp')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/decodedrew/contexpNoStimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Decoded; ContExpNoStimLoc')
plt.xlabel('Error (in Degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/RewThresh55/NoRew3/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Unit Difference; RewThresh 5.5')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/cont/NoRew3/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Unit Difference; Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/decodedrew/cont/NoRew3/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Decoded, Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/decodedrew/RewThresh30new/NoRew3/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Decoded; RewThresh 30')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/RewThresh55/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Unit Difference; RewThresh 5.5')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/cont/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Unit Difference; Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/decodedrew/cont/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Decoded, Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/decodedrew/RewThresh30new/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Decoded; RewThresh 30')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/RewThresh55/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Unit Difference; RewThresh 5.5')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/cont/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Unit Difference; Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/decodedrew/cont/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Decoded, Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/decodedrew/RewThresh30new/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Decoded; RewThresh 30')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/RewThresh55/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, Unit Difference; RewThresh 5.5')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/cont/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, Unit Difference; Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/decodedrew/cont/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, Decoded, Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/decodedrew/RewThresh30new/unifiedcode/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2, Decoded; RewThresh 30')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/RewThresh55/StimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Unit Difference; RewThresh 5.5')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/cont/StimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Unit Difference; Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/decodedrew/cont/StimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Decoded, Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/decodedrew/RewThresh30new/StimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Decoded; RewThresh 30')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/RewThresh55/"
files = os.listdir(base)
files = [f for f in files if ".csv" in f]
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Unit Difference; RewThresh 5.5')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/cont/"
files = os.listdir(base)
files = [f for f in files if ".csv" in f]
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Unit Difference; Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/decodedrew/cont/"
files = os.listdir(base)
files = [f for f in files if ".csv" in f]
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Decoded, Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/decodedrew/RewThresh30new/"
files = os.listdir(base)
files = [f for f in files if ".csv" in f]
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Decoded; RewThresh 30')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/RewThresh55/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Unit Difference; RewThresh 5.5')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/cont/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Unit Difference; Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/decodedrew/cont/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Decoded, Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/decodedrew/RewThresh30new/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Decoded; RewThresh 30')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/RewThresh55new/StimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_chunk, Unit Difference; RewThresh 5.5')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/cont/StimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_chunk, Unit Difference; Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/decodedrew/cont/StimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_chunk, Decoded, Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/decodedrew/RewThresh30new/StimLoc/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_chunk, Decoded; RewThresh 30')
plt.show()

# %%
# base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/RewThresh55/"
# files = os.listdir(base)
# full_files = [base+f for f in files if 'EpcLog' not in f]
# p = Precision()
# err_sir2_chunk_orig = p.mult_models(full_files)

# plt.figure()
# plt.hist(err_sir2_chunk_orig, bins = 50)
# plt.title('Sir3, Unit Difference; RewThresh 5.5')
# plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/cont/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Unit Difference; Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/decodedrew/cont/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3, Decoded, Continuous')
plt.show()

# base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/decodedrew/RewThresh30new/"
# files = os.listdir(base)
# full_files = [base+f for f in files if 'EpcLog' not in f]
# p = Precision()
# err_sir2_chunk_orig = p.mult_models(full_files)

# plt.figure()
# plt.hist(err_sir2_chunk_orig, bins = 50)
# plt.title('Sir3, Decoded; RewThresh 30')
# plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/RewThresh55new/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_chunk, Unit Difference; RewThresh 5.5')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/cont/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_chunk, Unit Difference; Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/decodedrew/cont/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_chunk, Decoded, Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/decodedrew/RewThresh30new/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_chunk, Decoded; RewThresh 30')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/decodedrew/RewThresh30new/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_new, Decoded, RewThresh 30')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/decodedrew/cont/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_new, Decoded; Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/RewThresh55/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_new, Unit Difference; RewThresh 5.5')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/cont/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_new, Unit Difference; Continuous')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/decodedrew/RewThresh30new/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Decoded; RewThres 30')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/decodedrew/cont/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Decoded; Continuous')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/RewThresh55/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Unit Difference; RewThresh 5.5')
plt.show()

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/cont/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir3_chunk, Unit Difference; Continuous')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/justchunk/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir3_chunk = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/justchunk/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/decodedrew/RewThresh30/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_nochunk = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/decodedrew/RewThresh30/orig/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir3_chunk_orig = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/RewThresh5/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_orig = p.mult_models(full_files)

# %%
plt.figure()
plt.hist(err_sir3_chunk, bins = 50)
plt.title('Sir3_chunk, Just chunk projects to PFC')
plt.show()

plt.figure()
plt.hist(err_sir2_chunk, bins = 50)
plt.title('Sir2_chunk, Just chunk projects to PFC')
plt.show()

plt.figure()
plt.hist(err_sir2_chunk_orig, bins = 50)
plt.title('Sir2_chunk')
plt.show()

plt.figure()
plt.hist(err_sir3_chunk_orig, bins = 50)
plt.title('Sir3_chunk')
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripe/hybrid/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/StimRange0to45/2Stripe/hybrid/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_chunk_NarrStim_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/StimRange0to45/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_nochunk_NarrStim_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir2_nochunk_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/2Stripe/hybrid/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir3_chunk_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/StimRange0to45/2Stripe/hybrid/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir3_chunk_NarrStim_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/StimRange0to45/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir3_nochunk_NarrStim_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files if 'EpcLog' not in f]
p = Precision()
err_sir3_nochunk_2Stripe = p.mult_models(full_files)

# %%
name = 'Sir2 No Chunk, 2 Stripes'
plt.hist(err_sir2_nochunk_2Stripe, bins = 70)
plt.title(name)
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
#plt.ylim([0,2500])
#plt.xlim([-30,30])
plt.show()

# %%
name = 'Sir2 No Chunk, 2 Stripes, Maximum Stim Difference:45'
plt.hist(err_sir2_nochunk_NarrStim_2Stripe, bins = 70)
plt.title(name)
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
#plt.ylim([0,2500])
#plt.xlim([-30,30])
plt.show()

# %%
name = 'Sir1 Chunk, 3 Stripes'
plt.hist(err_sir1_chunk_3Stripe, bins = 70)
plt.title(name)
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.ylim([0,2500])
plt.xlim([-30,30])
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_nochunk_3Stripe = p.mult_models(full_files)

name = 'Sir3 No Chunk, 3 Stripes'
plt.hist(err_sir2_nochunk_3Stripe, bins = 70)
plt.title(name)
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
#plt.ylim([0,2500])
#plt.xlim([-30,30])
plt.show()

# %%
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_chunk_3Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/StimRange0to45/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_chunk_NarrStim_3Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir3_chunk_3Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir3_chunk/results/Ring/StimRange0to45/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir3_chunk_NarrStim_3Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir3_3Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir3/results/Ring/StimRange0to45/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir3_NarrStim_3Stripe = p.mult_models(full_files)

# %%
name = 'Sir3 No Chunk, 3 Stripes, Maximum Stim Difference:45'
plt.hist(err_sir3_NarrStim_3Stripe, bins = 70)
plt.title(name)
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
#plt.ylim([0,2500])
#plt.xlim([-30,30])
plt.show()

# %%
name = 'Sir3 No Chunk, 3 Stripes'
plt.hist(err_sir3_3Stripe, bins = 70)
plt.title(name)
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
#plt.ylim([0,2500])
#plt.xlim([-30,30])
plt.show()

# %%
name = 'Sir1 Chunk, 3 Stripes'
plt.hist(err_sir1_chunk_3Stripe, bins = 70)
plt.title(name)
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.ylim([0,2500])
plt.xlim([-30,30])
plt.show()

# %%
#Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_nochunk_1Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_nochunk_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_nochunk_3Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_chunk_1Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_chunk_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir2_chunk_3Stripe = p.mult_models(full_files)

# %%
plt.hist(err_sir2_nochunk_3Stripe[:len(err_sir2_chunk_3Stripe)], bins = 70)
plt.title('Sir2 No Chunk, 3 Stripe, Maximum Stim Difference: 45')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir1 Ring
base = "Z:/leabra/examples/workingmemory/sir1/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir1_nochunk_1Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir1/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir1_nochunk_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir1/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir1_nochunk_3Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir1_chunk/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir1_chunk_1Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir1_chunk/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir1_chunk_2Stripe = p.mult_models(full_files)

base = "Z:/leabra/examples/workingmemory/sir1_chunk/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
p = Precision()
err_sir1_chunk_3Stripe = p.mult_models(full_files)

# %%
#sir2 no chunk model; 1 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir2 NO CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 no chunk model; 3 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir2 NO CHUNK- 3 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 no chunk model; 2 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir2 NO CHUNK- 2 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2chunk model; 2 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir2 CHUNK- 2 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2chunk model; 1 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir2 CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2chunk model; 3 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir2 CHUNK- 3 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir1 no chunk model; 1 stripe; Ring;
base = "Z:/leabra/examples/workingmemory/sir1/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir1 NO CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir1 no chunk model; 2 stripe; Ring;
base = "Z:/leabra/examples/workingmemory/sir1/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir1 NO CHUNK- 2 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir1 no chunk model; 3 stripe; Ring;
base = "Z:/leabra/examples/workingmemory/sir1/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir1 NO CHUNK- 3 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir1 chunk model; 1 stripe; Ring;
base = "Z:/leabra/examples/workingmemory/sir1_chunk/results/Ring/LargeJob/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir1 CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
#sir1 chunk model; 2 stripe; Ring;
base = "Z:/leabra/examples/workingmemory/sir1_chunk/results/Ring/LargeJob/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir1 CHUNK- 2 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir1 chunk model; 3 stripe; Ring;
base = "Z:/leabra/examples/workingmemory/sir1_chunk/results/Ring/LargeJob/3Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 70)
plt.title('Error Distribution for All Recall Trials, Sir1 CHUNK- 3 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir1, no chunk; 2 stripes
base = "C:/Users/Aneri/go/src/leabra/examples/sir_proj/sir1/"
files = ['trial1.csv']
full_files = [base+f for f in files]
p = Precision()
err = p.mult_models(full_files, sep = ',')
plt.hist(err)
plt.title('Error Distribution for All Recall Trials, Sir1 NO CHUNK- 2 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 no chunk model; 1 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/StimRange0to45/1StripeMore/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 40)
plt.title('Error Distribution for All Recall Trials, Sir2 NO CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 no chunk model; 2 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/StimRange0to45/2Stripes/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err)
plt.title('Error Distribution for All Recall Trials, Sir2 NO CHUNK - 2 Stripes')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 chunk model, 2 stripes; RING; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/StimRange0to45/2Stripes/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err)
plt.title('Error Distribution for All Recall Trials, Sir2 CHUNK - 2 Stripes')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 chunk model 1 stripe; Ring; stim range 0 to 45
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/StimRange0to45/1StripeMore/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 50)
plt.title('Error Distribution for All Recall Trials, Sir2 CHUNK - 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 no chunk model; 1 stripe; Ring
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
plt.subplot(1,2,1)
err = p.mult_models(full_files)
plt.ylim([0,120])
plt.hist(err, bins = 40)
plt.title('Sir2 NO CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')

#sir2 chunk model 1 stripe; Ring
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.subplot(1,2,2)
plt.ylim([0,120])
plt.hist(err, bins = 40)
plt.title('Sir2 CHUNK - 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#sir2 no chunk model; 1 stripe; Ring; stim 0  to45
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/StimRange0to45/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
plt.subplot(1,2,1)
err = p.mult_models(full_files)
plt.ylim([0,510])
plt.hist(err, bins = 40)
plt.title('Sir2 NO CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')

#sir2 chunk model 1 stripe; Ring;stom 0  to45
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/StimRange0to45/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.subplot(1,2,2)
plt.ylim([0,510])
plt.hist(err, bins = 40)
plt.title('Sir2 CHUNK - 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#sir2 no chunk model; 1 stripe; Ring
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 40)
plt.title('Error Distribution for All Recall Trials, Sir2 NO CHUNK- 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 no chunk model; 2 stripe; Ring
base = "Z:/leabra/examples/workingmemory/sir2_new/results/Ring/2Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err)
plt.title('Error Distribution for All Recall Trials, Sir2 NO CHUNK - 2 Stripes')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 chunk model 1 stripe; Ring
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/1Stripe/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err, bins = 40)
plt.title('Error Distribution for All Recall Trials, Sir2 CHUNK - 1 Stripe')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
len(err)
# Out:
# 1650

# %%
#sir2 chunk model, 2 stripes; RING
base = "Z:/leabra/examples/workingmemory/sir2_chunk/results/Ring/2Stripes/"
files = os.listdir(base)
full_files = [base+f for f in files]
#plotting errors for each model
# for i in range(len(full_files)):
#     plt.figure()
#     rel = Precision()
#     diffrecall = rel.mult_models([full_files[i]])
#     plt.hist(diffrecall)
#     plt.title('Error Histogram for model ' + str(i))

#selected_files = []

p = Precision()
err = p.mult_models(full_files)
plt.hist(err)
plt.title('Error Distribution for All Recall Trials, Sir2 CHUNK - 2 Stripes')
plt.xlabel('Error (in degrees)')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 model, 2 stripes (no chunk layer)
base = "Z:/leabra/examples/workingmemory/sir2_new/results/"
files = ['model1_Base.csv','model3_Base.csv','model4_Base.csv']
full_files = [base+f for f in files]


p = Precision()
err = p.mult_models(full_files)
plt.hist(err)
plt.title('Error Distribution for All Recall Trials')
plt.xlabel('Error')
plt.ylabel('Frequency')
plt.show()

# %%
#sir2 model, 2 stripes with chunk layer
base = "C:/Users/Aneri/go/src/leabra/examples/sir_proj/sir2_chunk/results/"
files = ['base.csv', 'base1.csv', 'base4.csv']
full_files = [base+f for f in files]
p = Precision()
err = p.mult_models(full_files,sep= ',')
plt.hist(err)
plt.title('Error Distribution for All Recall Trials')
plt.xlabel('Error')
plt.ylabel('Frequency')
plt.show()
